# %%
# %run notebooks/Markers_calcul001.ipynb
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File /var/folders/s7/l40675nx1_b8x31mxcqljfqr0000gn/T/ipykernel_83362/323408175.py:19
#      15 cycleMaxNumber = 6
#      16 cycleDuration = 20
# ---> 19 data = np.loadtxt("/Users/matysprecloux/Desktop/Master IEAP/IEAP-project/Circular-task-analysis:/Data/001MoDe_R1.csv",
#      20                   delimiter=',',skiprows=1)
#      22 # skiprows=1 -> skip the header containing column names
#      24 timestamps_ms = data[:,0]
#
# File /opt/miniconda3/lib/python3.13/site-packages/numpy/lib/_npyio_impl.py:1397, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1394 if isinstance(delimiter, bytes):
#    1395     delimiter = delimiter.decode('latin1')
# -> 1397 arr = _read(fname, dtype=dtype, comment=comment, delimiter=delimiter,
# ...
